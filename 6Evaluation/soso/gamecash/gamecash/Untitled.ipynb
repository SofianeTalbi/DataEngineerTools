# %%
import pandas as pd

# %%
df = pd.read_json('soso.json')

# %%
df
# Out:
#                                        Nom \nPlate-forme :   \
# 0                     51 Worldwide Games             Switch
# 1   Little Nightmares II: Day One Edition          Xbox One
# 2     Marvel's Spider-Man : Miles Morales    Playstation 4
# 3                           Sea of Thieves         Xbox One
# 4             Tom Clancy's The Division 2    Playstation 4
# ..                                     ...              ...
# 57          Animal Crossing: New Horizons            Switch
# 58                                FIFA 20          Xbox One
# 59                             MXGP 2019     Playstation 4
# 60      Console Nintendo Switch Lite Grise           Switch
# 61                         Death Stranding   Playstation 4
#
#            \nGenre :      \nEditeur :             \nLanguage :   \
# 0      Jeu de société         Nintendo  Français (Texte + Voix)
# 1     Action-Aventure     Bandai Namco                      NaN
# ...
